# %% [markdown]
# ## IMDb- Web Scraping

# %% [markdown]
# ### Importing important libraries

# %%
from bs4 import BeautifulSoup
import requests,openpyxl

# %% [markdown]
# ### Creating an excel file to store the scraped data

# %%
excel=openpyxl.Workbook()
print(excel.sheetnames)
sheet=excel.active
sheet.title= "Top Rated Movies"
sheet.append(["Movie Rank","Movie Name","Year of release"," IMDB Rating"])
# Out:
# ['Sheet']

# %% [markdown]
# ### The url of the IMDB website we want to scrape

# %%
    source =requests.get('https://www.imdb.com/chart/top/')
    source.raise_for_status()
    
    soup=BeautifulSoup(source.text,'html.parser')
    
    movies=soup.find('tbody',class_="lister-list").find_all('tr')
    print(movies)
# Out:
# [<tr>
# <td class="posterColumn">
# <span data-value="1" name="rk"></span>
# <span data-value="9.236244920191663" name="ir"></span>
# <span data-value="7.791552E11" name="us"></span>
# <span data-value="2753767" name="nv"></span>
# <span data-value="-1.7637550798083375" name="ur"></span>
# <a href="/title/tt0111161/"> <img alt="The Shawshank Redemption" height="67" src="https://m.media-amazon.com/images/M/MV5BNDE3ODcxYzMtY2YzZC00NmNlLWJiNDMtZDViZWM2MzIxZDYwXkEyXkFqcGdeQXVyNjAwNDUxODI@._V1_UX45_CR0,0,45,67_AL_.jpg" width="45"/>
# </a> </td>
# <td class="titleColumn">
#       1.
#       <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
# <span class="secondaryInfo">(1994)</span>
# </td>
# <td class="ratingColumn imdbRating">
# <strong title="9.2 based on 2,753,767 user ratings">9.2</strong>
# </td>
# <td class="ratingColumn">
# <div class="seen-widget seen-widget-tt0111161 pending" data-titleid="tt0111161">
# ...

# %% [markdown]
#  As we can see the HTML code, the data can be scraped from this code.

# %%
print(len(movies))
# Out:
# 250

# %% [markdown]
# There are total of 250 movies

# %% [markdown]
# ### The data we will extract from IMDB website  is : Movie rank, Movie name, Year of release and IMDB Rating

# %% [markdown]
# #### First we are scraping one element from the website and accordingly all the data will be extracted.

# %% [markdown]
# 1.Right click on the data we want to extract and click on Inspect.
# 2.A window with HTML code will appear on the right side of the webpage.
# 3.Find the container in which the data we want to extract is stored.

# %% [markdown]
# #### Extracting first movie name

# %%
name=movie.find('td',class_="titleColumn").a.text

# %% [markdown]
# #### Similarly, we will extract rest of the information for the first movie.

# %%
# Extracting rank of the movie
rank=movie.find('td',class_="titleColumn").get_text(strip=True).split(".")[0]

# %% [markdown]
# #### Extracting year of release

# %%
year=movie.find('td',class_="titleColumn").span.text.strip('()')

# %% [markdown]
# #### The last thing we need to extract is imdb ratinngs.

# %%
rating=movie.find('td',class_="ratingColumn imdbRating").strong.text

# %% [markdown]
# #### We have total of 250 movies. So, instead of specifying URL each time, we will write a loop to extract the complete 250 rows and store it in the sheet

# %%
for movie in movies:
        name=movie.find('td',class_="titleColumn").a.text
        rank=movie.find('td',class_="titleColumn").get_text(strip=True).split(".")[0]
        year=movie.find('td',class_="titleColumn").span.text.strip('()')
        rating=movie.find('td',class_="ratingColumn imdbRating").strong.text
        print(rank,name,year,rating)
        sheet.append([rank,name,year,rating])

# %% [markdown]
# ### Save the excel file

# %%
excel.save('IMDB Movie Rating.xlsx')
